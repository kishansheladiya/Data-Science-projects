# %%
import pandas as pd
from pytrends.request import TrendReq
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")
Trending_topics = TrendReq(hl= 'en-US', tz=360)

# %% [markdown]
# ### Build Payload
#
# Now, we will create a data frame of the top 10 countries that search for the term "Data Analyst". For this, we will be using the method build_payload, which allows storing a list of keywords that you want to search. In this, you can also specify the timeframe and the categoryy to query the data from.

# %%
kw_list= ["Data Analyst"]
Trending_topics.build_payload(kw_list,cat=0, timeframe='now 7-d')

# %% [markdown]
# ### Interest over time
#
# This method, returns the historical, indexed data for when the specified keyword was most searched according to the timeframe mentioned in the build payload method.

# %%
Trending_topics.build_payload(kw_list=["Data Analyst"], cat=0, timeframe='now 7-d')
data = Trending_topics.interest_over_time()
data = data.sort_values(by="Data Analyst", ascending = False)
data= data.head(10)
print(data)
# Out:
#                      Data Analyst  isPartial
# date
# 2024-06-03 07:00:00           100      False
# 2024-06-08 12:00:00            99      False
# 2024-06-06 05:00:00            97      False
# 2024-06-03 06:00:00            95      False
# 2024-06-05 07:00:00            94      False
# 2024-06-06 06:00:00            94      False
# 2024-06-06 07:00:00            94      False
# 2024-06-06 08:00:00            94      False
# 2024-06-01 13:00:00            93      False
# 2024-06-03 05:00:00            93      False

# %% [markdown]
# ### Historical Hour Interest
#
# The get_historical_interest() method returns the historical, indexed, hourly data for when the specified keyword was most searched. You can also mention various time period parameters for which you want the hostorical data such as year_start, month_start, hour_start, year_end, month_end, day_end, and hour_end.

# %%
data = Trending_topics.interest_by_region() 
data = data.sort_values(by="Data Analyst",ascending = False) 
data = data.head(10) 
print(data)
# Out:
#                       Data Analyst
# geoName
# Nigeria                        100
# Kenya                           99
# India                           89
# Singapore                       84
# South Africa                    66
# Sri Lanka                       60
# United Kingdom                  58
# Canada                          58
# Ghana                           53
# United Arab Emirates            50

# %%
data.reset_index().plot(x= 'geoName', y='Data Analyst', figsize=(27,3), kind='bar')
plt.style.use('fivethirtyeight')
plt.show()

# %% [markdown]
# ### Related Queries
#
# Whenever a user searches for something about a particular topic on google there is a high probability that the user will search for more queries related to the same topic. These are known as related queries. Let us find a list of related queries for "Fire Safety"

# %%
Trending_topics.build_payload(kw_list=['Data Analyst'])
related_queries= Trending_topics.related_queries()
related_queries.values()
# Out:
# dict_values([{'top':                                query  value
# 0                  data analyst jobs    100
# 1                data analyst salary     92
# 2                   data analyst job     54
# 3                   business analyst     39
# 4              business data analyst     39
# 5               what is data analyst     37
# 6                     data analytics     31
# 7                     data scientist     26
# 8                       data science     26
# 9             what is a data analyst     22
# 10                     data analysis     21
# 11               google data analyst     20
# 12                     data engineer     17
# 13        data analyst certification     14
# 14      data analyst job description     13
# 15               data analyst skills     13
# 16               data analyst resume     13
# 17                               sql     13
# 18                          linkedin     12
# 19  data analyst interview questions     12
# 20                   data entry jobs     12
# 21               data analyst career     11
# 22           data analyst internship     11
# 23              data analyst courses     10
# 24                            python     10, 'rising':                                          query  value
# 0    ibm data analyst professional certificate  27700
# 1   microsoft certified data analyst associate   2250
# 2                         data analyst roadmap   1650
# 3                                     power bi    850
# 4          google data analytics certification    750
# 5         microsoft data analyst certification    450
# 6                           data analyst là gì    450
# 7                     remote data analyst jobs    400
# 8                                  remote jobs    400
# 9                          data analyst adalah    350
# 10               is data analyst a good career    300
# 11                           gaji data analyst    200
# 12               data analyst vs data engineer    140
# 13                   data analyst jobs near me    140
# 14                                       udemy    130
# 15                      what is a data analyst    100
# 16                  data analyst certification     80
# 17                                      python     70
# 18                               data engineer     70
# 19                         google data analyst     60
# 20                        what is data analyst     50
# 21                         data analyst skills     40
# 22                     data analyst internship     40}])
